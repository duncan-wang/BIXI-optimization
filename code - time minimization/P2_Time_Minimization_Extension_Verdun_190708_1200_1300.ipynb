# %%
import gurobipy as gp
from gurobipy import *
import numpy as np
import pandas as pd

# %% [markdown]
# ## Problem 2. Operation Time Optimization

# %% [markdown]
# ### Parameters
# - $d_{i,j}$: The distance between station $i$ and station $j$.
# - $e_i$: The existing number of bikes at station $i$ before rebalancing.
# - $I_i = [\lambda_i - \omega_i, \lambda_i + \omega_i]$: The ideal threshold of bikes at station $i$ after rebalancing, which is represented by a predetermined idea amount $\lambda_i$ associated with a symmetric threshold of $2\omega_i$.
# - $\gamma_i$: Capacity (number of docks) of bike station $i$.
# - $n$: Number of stations.
# - $C$: Capacity of the truck.
# - $s_{i}^+$: A binary value that indicates whether there is a bike surplus at station $i$, i.e. $s_{i}^+ = 1$ when $E_i > \lambda_i + \omega_i$, and zero otherwise.
# - $s_{i}^-$: A binary value that indicates whether there is a bike shortage at station $i$, i.e. $s_{i}^- = 1$ when $E_i < \lambda_i - \omega_i$, and zero otherwise.

# %%
#Data importing and preprocessing
Verdun_stations = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/Verdun_stations.csv')
Verdun_dock_capacity = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/Verdun_dock_capacity.csv')

Verdun_dock_capacity = Verdun_dock_capacity.drop(columns=['Unnamed: 0'])
Verdun_stations = Verdun_stations.drop(columns=['Unnamed: 0'])

Verdun_dock_capacity = Verdun_dock_capacity.rename(columns = {'station_code': 'Code', 'dock capacity': 'capacity'})
Verdun_stations = Verdun_stations.join(Verdun_dock_capacity.set_index('Code'), on = 'Code')

n = Verdun_stations.shape[0]
#stations = [coordinates of each station]
stations = [[np.array(Verdun_stations.latitude)[i], np.array(Verdun_stations.longitude)[i]] for i in range(n)]

# %%
Verdun_net_balance20190708 = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/net_balance2019-07-08.csv')
Verdun_net_balance20190708 = Verdun_net_balance20190708.drop(columns=['Unnamed: 0'])

#Use the demand of '7/8/19 8:00' as an example
diff = np.array(Verdun_net_balance20190708['7/8/19 8:00'])

# %%
cap = np.array(Verdun_stations['capacity'])
ideal_level = np.floor(cap * 0.7) #ideal level is at 70%
ideal_level = ideal_level.astype(int)

#Existing number of bikes at stations, list of integers of length n
E = np.floor(cap * 0.7) + diff
E = E.astype(int)

#Manhattan Distance
#@ith WGS 1984 coordinate projection 111, 1 degree = 111 KM
d_m = [[111 * abs(i[0] - j[0]) + 111 * abs(i[1] - j[1]) for i in stations] for j in stations]

threshold = 3
I = [[ideal_level[i] - threshold, ideal_level[i] + threshold] for i in range(n)]


#Capacity of the truck
C = 40

#Binary values indicates surplus/shortage at staion i
s1 = [int(E[i] - I[i][1] > 0) for i in range(n)] #surplus
s2 = [int(I[i][0] - E[i] > 0) for i in range(n)] #shortage

#Obj parameters: wages and costs

# %% [markdown]
# ### Variables
# - $x_{i,j}$: A binary variable that indicates the relocation truck passes through station $i$ to station $j$ if $x_{i,j} = 1$, and zero otherwise.
# - $c_{i}$: The current number of bikes on the truck before arriving at station $i$.
# - $d_{i}$: The number of bikes the truck drops off at station $i$.
# - $p_{i}$: The number of bikes the truck picks up at station $i$.
#
# ### Dummy Variables
# - $z_i$: Non-decreasing variables to ensure continuity of the route, for $i \in \{1 \dots n\}$.
#
#
# ### Other Notations
# - $B$: The total number of bikes that are relocated.
# - $D$: The total distance that the truck has traveled.
# - $V$: The total number of stations visited (for record tracking purpose ONLY).

# %%
#Profit Maximization Model
prob = Model('BIXI')

x = prob.addVars(n, n, vtype='B', name = 'x') #BINARY: x_{i,j}
c = prob.addVars(n,lb = 0, vtype='I', name = 'c') #INTEGER: c_i 
d = prob.addVars(n,lb = 0, vtype='I', name = 'd') #INTEGER: d_i
p = prob.addVars(n,lb = 0, vtype='I', name = 'p') #INTEGER: p_i
z = prob.addVars(n,lb = 0, name = 'z')

B = prob.addVar(lb = 0, vtype='I', name = 'B') #INTEGER: total number of bikes rebalanced
D = prob.addVar(lb = 0, name = 'D') #INTEGER: total distance travelled by truck

#Variable to check accuracy
V = prob.addVar(lb = 0, vtype='I', name = 'V') #INTEGER, total number of stations visited
d_sum = prob.addVar(lb = 0, vtype='I', name = 'd_sum') #INTEGER, total number of bikes dropped off
p_sum = prob.addVar(lb = 0, vtype='I', name = 'p_sum') #INTEGER, total number of bikes picked up

# %% [markdown]
# ### Assumptions
# - Routing
#   - 1. Each station is visited at most once. (Routing-1)
#   - 2. The truck starts at station 0 and ends at station 0. (Routing-2)
#   - 3. The distance will be calcuated using Manhattan distance.
# - Rebalancing
#   - 1. The truck arrives at station 0 with 20 bikes at the beginning of each working hour.
#   - 2. The operational cost has three components, the wage for the worker, gas cost and disinfecting cost.

# %% [markdown]
# ### Variations
# - fixed subpath on bike stations located near hospitals, extra cost for disinfecting during COVID-19
# - Nonlinear objective

# %% [markdown]
# ### Objective
# $$\text{Minimize } \big( b * B + d * D + s * V\big)$$

# %%
obj = 1.5 * B + 3 * D + 2 * V
prob.setObjective(obj, GRB.MINIMIZE)

# %% [markdown]
# ### Constraints - Routing
#
# $$\begin{align}
# \sum_i x_{ij} & \le 1 \hspace{0.5cm} i = \{2 \dots n\} \tag{Routing-1.1}\\
# \sum_j x_{ij} & \le 1 \hspace{0.5cm} j = \{2 \dots n\} \tag{Routing-1.2}\\
# \sum_i x_{ij} & = \sum_i x_{ji} \hspace{0.5cm} \tag{Routing-1.3}\\
# \sum_i x_{ii} & = 0 \hspace{0.5cm} \tag{Routing-1.4}\\
# \sum_i x_{i1} & = 1 \tag{Routing-2.1}\\
# \sum_j x_{1j} & = 1 \tag{Routing-2.2}\\
# \sum_{i,j} x_{ij} d_{ij} & = D  \tag{Total distance}\\
# z_j & \ge z_i + 1 - 1996(1 - x_{ij}) \tag{Continuity of route}\\
# \end{align}$$

# %%
#---Routing---

#Routing-1.1
for j in range(n):
    prob.addConstr(quicksum(x[i,j] for i in range(n)) <= 1)
    
#Routing-1.2    
for i in range(n):
    prob.addConstr(quicksum(x[i,j] for j in range(n)) <= 1)

#Routing-1.3
for i in range(n):
    prob.addConstr(quicksum(x[i,j] for j in range(n)) == quicksum(x[j,i] for j in range(n))) 

#Routing-1.4
for i in range(1,n):
    prob.addConstr(x[i,i] == 0)    

#Total Distance
prob.addConstr(quicksum(x[i,j] * d_m[i][j] for i in range(n) for j in range(n)) == D)

#Route Continuity
#Avoid sub trips by implementing a non-decreasing variable z
#When the truck travels from i to j, z[j] > z[i]
for i in range(n):
    for j in range(1,n):
        prob.addConstr(z[j] >= z[i] + 1 - 1996 * (1 - x[i,j]))

# %% [markdown]
# ### Constraints - Rebalancing
#
# $$\begin{align}
# c_i & \le C \tag{Capacity of the truck}\\
# s_i^- d_i + s_i^+ p_i & = 0 \tag{Pick up XOR Drop off at any station}\\
# p_i & \le E_i \tag{Pick up within ideal threshold}\\
# \sum_i d_i & \le \sum_i p_i \tag{Drop off LESS THAN pick up}\\
# \sum_i d_i + p_i & = B \tag{Total amount of bikes rebalanced}\\
# d_j + p_j & \ge \sum_i x_{ij} \tag{A station is visted when necessary}\\
# c_j + d_j + p_j + \alpha_j & \le 1996\sum_i x_{ij} \tag{A station is visted when necessary}\\
# c_j & \ge c_i - d_i + p_i - C(1 - x_{ij}) \hspace{0.5cm} \tag{Continuity of truck inventory - 1}\\
# c_j & \le c_i - d_i + p_i - C(1 - x_{ij}) \hspace{0.5cm} \tag{Continuity of truck inventory - 2}\\
# \end{align}$$

# %%
#---Rebalancing---     
        
#Truck arrives at station 1 with 20 bikes
prob.addConstr(c[0] == 20)


for i in range(1,n):
    #Pick up XOR Drop off at any station
    prob.addConstr(s1[i] * d[i] + s2[i] * p[i] == 0)

    #Capacity of the truck
    prob.addConstr(c[i] <= C)
    
    #pick up within ideal threshold
    prob.addConstr(p[i] <= E[i])
    prob.addConstr(p[i] >= E[i] - I[i][1])
    
    #drop off within ideal threshold
    prob.addConstr(d[i] <= cap[i] - E[i])
    prob.addConstr(d[i] >= (I[i][0] - E[i])) #nonbinding when surplus  
    
#Total amount of bikes rebalanced
prob.addConstr(quicksum(p[i] + d[i] for i in range(n)) == B)

#A station is visted when necessary (synergy with the route)
for i in range(1,n):
    prob.addConstr(d[i] + p[i] >= quicksum(x[j,i] for j in range(n)))
    #when station i is not visited LHS = RHS = 0
    #when station i is visited 
    prob.addConstr(c[i] + d[i] + p[i] + z[i] <= 2 * C * quicksum(x[j,i] for j in range(n)))
                   

#Continuity of truck inventory
for i in range(n):
    for j in range(1,n):
        prob.addConstr(c[j] <= c[i] - d[i] + p[i] + C * (1 - x[i,j]))
        prob.addConstr(c[j] >= c[i] - d[i] + p[i] - C * (1 - x[i,j]))

# %%
#---Variables for record tracking---           
prob.addConstr(quicksum(x[i,j] for i in range(n) for j in range(n)) == V)    
prob.addConstr(quicksum(d[i] for i in range(n)) == d_sum)
prob.addConstr(quicksum(p[i] for i in range(n)) == p_sum)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %%
prob.optimize()
prob.printAttr('X')
# Out:
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1131 rows, 401 columns and 6664 nonzeros
# Model fingerprint: 0x1def7a69
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 184 rows and 30 columns
# Presolve time: 0.02s
# Presolved: 947 rows, 371 columns, 5164 nonzeros
# Variable types: 17 continuous, 354 integer (308 binary)
#
# Root relaxation: objective 2.693069e+01, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   26.93069    0   15          -   26.93069      -     -    0s
# H    0     0                      80.7740528   26.93069  66.7%     -    0s
# H    0     0                      35.6826458   26.93069  24.5%     -    0s
#      0     0   33.62018    0    6   35.68265   33.62018  5.78%     -    0s
#      0     0   33.62018    0    8   35.68265   33.62018  5.78%     -    0s
#      0     0   33.62018    0    8   35.68265   33.62018  5.78%     -    0s
#      0     0   33.68265    0   13   35.68265   33.68265  5.60%     -    0s
#      0     0   34.03092    0   13   35.68265   34.03092  4.63%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Implied bound: 1
#   MIR: 7
#   Zero half: 1
#
# Explored 1 nodes (111 simplex iterations) in 0.09 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 35.6826 80.7741
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.568264583070e+01, best bound 3.568264583070e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,6]            1
#      x[2,16]            1
#       x[5,0]            1
#       x[6,2]            1
#      x[16,5]            1
#         c[0]           20
#         c[2]           19
#         c[5]           16
#         c[6]           20
#        c[16]           17
#         d[2]            2
#         d[6]            1
#        d[16]            1
#         p[5]            2
#         z[2]            2
#         z[5]            4
#         z[6]            1
#        z[16]            3
#            B            6
#            D      5.56088
#            V            5
#        d_sum            4
#        p_sum            2

# %%
print('Total time July 8th 8:00AM - 9:00AM: ' + str(round(obj.getValue(),2)))
print('The driver travelled {} stations and rebalanced {} bikes (picked up {} bikes and dropped off {} bikes).'.format(V.x, B.x, p_sum.x, d_sum.x))
# Out:
# Total time July 8th 8:00AM - 9:00AM: 35.68
# The driver travelled 5.0 stations and rebalanced 6.0 bikes (picked up 2.0 bikes and dropped off 4.0 bikes).

# %% [markdown]
# ### Now we wrap everything into one function, which automatically updates the number of bikes at each station after riders pick up, drop off and the rebalancing, and simulate the rebalancing for July 8th.

# %%
def hour_rebalance0(df):
# def hour_rebalance1(df):
    
    bikes_rebalanced = []
    before = []
    after = []
    visits = []
    time = []
    
    n = len(stations)
    
    daily_cost = 0
    bikes = 0
    
    C = 40
    d_m = [[111 * abs(i[0] - j[0]) + 111 * abs(i[1] - j[1]) for i in stations] for j in stations]
    
    ss = 0
#     speed = [4,3.5,3,3,3.5,3.5,3,3,3.5,4,3.5,3]
    speed = [3,2,2,2,3,3,2,2,3,3,3,2]
    
    cap = np.array(Verdun_stations['capacity'])
    ideal_level = np.floor(cap * 0.7)
    E = ideal_level
    
    
    hr = 8
    threshold = 3
            
    I = [[ideal_level[i] - threshold, ideal_level[i] + threshold] for i in range(n)]
    
    #Obj parameters: wages and costs
    

    for col in list(df.columns)[2:14]:
        
#         if hr == 12 or hr == 13 or hr == 14:
#             threshold = 4
#         elif hr == 9 or hr == 10 or hr == 11:
#             threshold = 2
#         else:
#             threshold = 3

        I = [[ideal_level[i] - threshold, ideal_level[i] + threshold] for i in range(n)]
        
        print('threshold')
        print(threshold)
        
        diff = np.array((df[col]))
        E = E + diff
        before.append(E)
        print(col)
        print(E)

        #Binary values indicates surplus/shortage at staion i
        s1 = [int(E[i] - I[i][1] > 0) for i in range(n)] #surplus
        s2 = [int(I[i][0] - E[i] > 0) for i in range(n)] #shortage

        
        prob = Model('BIXI')

        x = prob.addVars(n, n, vtype='B', name = 'x') #BINARY
        c = prob.addVars(n,lb = 0, vtype='I', name = 'c') #INTEGER
        d = prob.addVars(n,lb = 0, vtype='I', name = 'd') #INTEGER
        p = prob.addVars(n,lb = 0, vtype='I', name = 'p') #INTEGER
        z = prob.addVars(n,lb = 0, name = 'z')

        B = prob.addVar(lb = 0, vtype='I', name = 'B') #INTEGER
        D = prob.addVar(lb = 0, name = 'D') #INTEGER

        #Variable to check accuracy
        V = prob.addVar(lb = 0, vtype='I', name = 'V') #INTEGER
        d_sum = prob.addVar(lb = 0, vtype='I', name = 'd_sum') #INTEGER
        p_sum = prob.addVar(lb = 0, vtype='I', name = 'p_sum') #INTEGER

        obj = 1.5 * B + speed[ss] * D + 2 * V
        prob.setObjective(obj, GRB.MINIMIZE)


        #---Routing---

        #TSP-1.1
        for j in range(n):
            prob.addConstr(quicksum(x[i,j] for i in range(n)) <= 1)

        #TSP1.2    
        for i in range(n):
            prob.addConstr(quicksum(x[i,j] for j in range(n)) <= 1)

        #TSP-1.3
        for i in range(n):
            prob.addConstr(quicksum(x[i,j] for j in range(n)) == quicksum(x[j,i] for j in range(n))) 

        #TSP-1.4
        for i in range(1,n):
            prob.addConstr(x[i,i] == 0)    

        #Total Distance
        prob.addConstr(quicksum(x[i,j] * d_m[i][j] for i in range(n) for j in range(n)) == D)

        #Route Continuity
        for i in range(n):
            for j in range(1,n):
                prob.addConstr(z[j] >= z[i] + 1 - 1996 * (1 - x[i,j]))


        #---Rebalancing---     

        #Empty Truck
        prob.addConstr(c[0] == 20)


        for i in range(n):
            #Capacity of the truck
            prob.addConstr(c[i] <= C)

            #pick up within ideal threshold
            prob.addConstr(p[i] <= E[i])
            prob.addConstr(p[i] >= E[i] - I[i][1])

            #drop off within ideal threshold
            prob.addConstr(d[i] <= cap[i] - E[i])
            prob.addConstr(d[i] >= (I[i][0] - E[i])) #nonbinding when surplus ???    

        #Total amount of bikes rebalanced
        prob.addConstr(quicksum(p[i] + d[i] for i in range(n)) == B)

        for i in range(1,n):
            #Pick up XOR Drop off at any station
            prob.addConstr(s1[i] * d[i] + s2[i] * p[i] == 0)

        #A station is visted when necessary (synergy with the route)
        for i in range(1,n):
            prob.addConstr(d[i] + p[i] >= quicksum(x[j,i] for j in range(n)))
            prob.addConstr(c[i] + d[i] + p[i] <= 2 * C * quicksum(x[j,i] for j in range(n)))


        #Continuity of truck inventory
        for i in range(n):
            for j in range(1,n):
                prob.addConstr(c[j] <= c[i] - d[i] + p[i] + C * (1 - x[i,j]))
                prob.addConstr(c[j] >= c[i] - d[i] + p[i] - C * (1 - x[i,j]))


        #---Variables to check accuracy---           
        prob.addConstr(quicksum(x[i,j] for i in range(n) for j in range(n)) == V)       
        prob.addConstr(quicksum(d[i] for i in range(n)) == d_sum) 
        prob.addConstr(quicksum(p[i] for i in range(n)) == p_sum) 


        prob.optimize()

        prob.printAttr('X')
        
        #Update existing bikes after rebalancing
        E = [E[i] - p[i].x + d[i].x for i in range(n)]
        after.append(E)
        
        operation_time = round(obj.getValue(),2)
        
        hr += 1

        
#         if operation_time > 50:
#             threshold = 2
#         else:
#             threshold = 3
            
        
        ss += 1
        
        bikes_rebalanced.append(B.x)
        bikes = bikes + B.x
        
        visits.append(V.x)
    
        
        time.append(round(obj.getValue(),2))
        print(col)
#         print(E)
#         print(round(obj.getValue(),2))
    

    return time,visits

# %% [markdown]
# ### Here we simulate the rebalancing for July 8 (14 working hours).

# %%
time0,visits0 = hour_rebalance0(Verdun_net_balance20190710)
# Out:
# threshold
# 3
# 7/10/19 9:00
# [21. 15. 18.  9. 10.  6. 10. 11. 10.  7.  8.  8.  4.  6.  7.  3.  4.  3.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6652 nonzeros
# Model fingerprint: 0x3a019bc0
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 193 rows and 29 columns
# Presolve time: 0.01s
# Presolved: 943 rows, 372 columns, 5173 nonzeros
# Variable types: 17 continuous, 355 integer (306 binary)
#
# Root relaxation: objective 3.478785e+01, 37 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   34.78785    0   12          -   34.78785      -     -    0s
# H    0     0                      67.6282178   34.78785  48.6%     -    0s
# H    0     0                      61.3372815   34.78785  43.3%     -    0s
# H    0     0                      58.9021491   34.78785  40.9%     -    0s
#      0     0   36.75525    0   14   58.90215   36.75525  37.6%     -    0s
# H    0     0                      51.4021491   36.75525  28.5%     -    0s
#      0     0   36.75525    0   13   51.40215   36.75525  28.5%     -    0s
# H    0     0                      44.6579330   36.75525  17.7%     -    0s
#      0     0   38.69300    0   14   44.65793   38.69300  13.4%     -    0s
#      0     0   38.78965    0   13   44.65793   38.78965  13.1%     -    0s
#      0     0   38.78965    0   14   44.65793   38.78965  13.1%     -    0s
# H    0     0                      43.3372815   38.78965  10.5%     -    0s
#      0     0   38.88641    0    9   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   12   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   16   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   18   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   11   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   10   43.33728   38.88641  10.3%     -    0s
# H    0     0                      41.1579330   38.88641  5.52%     -    0s
#      0     0   38.88641    0    8   41.15793   38.88641  5.52%     -    0s
#      0     0     cutoff    0        41.15793   41.15793  0.00%     -    0s
#
# Explored 1 nodes (200 simplex iterations) in 0.16 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 41.1579 43.3373 44.6579 ... 67.6282
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.115793298673e+01, best bound 4.115793298673e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,5]            1
#      x[2,17]            1
#       x[5,2]            1
#      x[15,0]            1
#     x[17,15]            1
#         c[0]           20
#         c[2]           20
#         c[5]           21
#        c[15]           20
#        c[17]           21
#         d[5]            1
#        d[15]            1
#        d[17]            1
#         p[0]            1
#         p[2]            1
#         z[2]            2
#         z[5]            1
#        z[15]            4
#        z[17]            3
#            B            5
#            D      7.88598
#            V            5
#        d_sum            3
#        p_sum            2
# 7/10/19 9:00
# threshold
# 3
# 7/10/19 10:00
# [21. 13. 17. 11. 10.  7. 10. 10. 10.  6.  8.  8.  1.  6.  6.  4.  4.  4.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6650 nonzeros
# Model fingerprint: 0x30e51c1b
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 81.8109225
# Presolve removed 187 rows and 27 columns
# Presolve time: 0.01s
# Presolved: 949 rows, 374 columns, 5383 nonzeros
# Variable types: 17 continuous, 357 integer (306 binary)
#
# Root relaxation: objective 2.224526e+01, 33 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   22.24526    0    9   81.81092   22.24526  72.8%     -    0s
# H    0     0                      61.8738626   22.24526  64.0%     -    0s
# H    0     0                      32.8768812   22.24526  32.3%     -    0s
# H    0     0                      27.7957471   22.24526  20.0%     -    0s
# H    0     0                      25.7957471   22.24526  13.8%     -    0s
#      0     0   22.32543    0    8   25.79575   22.32543  13.5%     -    0s
#      0     0   22.32543    0    8   25.79575   22.32543  13.5%     -    0s
# H    0     0                      24.2957471   22.32543  8.11%     -    0s
#      0     0     cutoff    0        24.29575   24.29575  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Implied bound: 1
#   RLT: 8
#   Relax-and-lift: 1
#
# Explored 1 nodes (59 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 24.2957 25.7957 27.7957 ... 81.8109
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.429574708826e+01, best bound 2.429574708826e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,12]            1
#       x[9,0]            1
#      x[12,9]            1
#         c[0]           20
#         c[9]           18
#        c[12]           21
#         d[9]            1
#        d[12]            3
#         p[0]            1
#         z[9]            2
#        z[12]            1
#            B            5
#            D      5.39787
#            V            3
#        d_sum            4
#        p_sum            1
# 7/10/19 10:00
# threshold
# 3
# 7/10/19 11:00
# [24. 17. 16. 12. 10.  9. 12. 10.  9.  8.  8.  7.  4.  4.  6.  4.  1.  4.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6649 nonzeros
# Model fingerprint: 0xc3e03965
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 184 rows and 26 columns
# Presolve time: 0.01s
# Presolved: 952 rows, 375 columns, 5488 nonzeros
# Variable types: 17 continuous, 358 integer (307 binary)
# Found heuristic solution: objective 20.5460527
#
# Root relaxation: objective 1.739773e+01, 18 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0        20.54605   20.54605  0.00%     -    0s
#
# Explored 0 nodes (36 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 20.5461
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.054605273473e+01, best bound 2.054605273473e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,16]            1
#      x[16,0]            1
#         c[0]           20
#        c[16]           24
#        d[16]            3
#         p[0]            4
#        z[16]            1
#            B            7
#            D      3.02303
#            V            2
#        d_sum            3
#        p_sum            4
# 7/10/19 11:00
# threshold
# 3
# 7/10/19 12:00
# [23. 18. 18. 13. 12.  7. 12. 10.  7.  8.  9.  6.  1.  4.  6.  3.  2.  4.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6654 nonzeros
# Model fingerprint: 0xefe59846
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 199 rows and 31 columns
# Presolve time: 0.01s
# Presolved: 937 rows, 370 columns, 4963 nonzeros
# Variable types: 17 continuous, 353 integer (306 binary)
#
# Root relaxation: objective 4.264631e+01, 49 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   42.64631    0   12          -   42.64631      -     -    0s
#      0     0   43.01630    0   17          -   43.01630      -     -    0s
# H    0     0                      78.5163716   43.01630  45.2%     -    0s
#      0     0   43.01630    0   15   78.51637   43.01630  45.2%     -    0s
# H    0     0                      50.0163716   43.01630  14.0%     -    0s
# H    0     0                      47.7193111   43.01630  9.86%     -    0s
#      0     0   43.11453    0   16   47.71931   43.11453  9.65%     -    0s
#      0     0   43.11517    0   14   47.71931   43.11517  9.65%     -    0s
#      0     0   43.67005    0   14   47.71931   43.67005  8.49%     -    0s
#      0     0   43.67005    0   12   47.71931   43.67005  8.49%     -    0s
#      0     0   43.67005    0   16   47.71931   43.67005  8.49%     -    0s
# H    0     0                      47.2712820   43.67005  7.62%     -    0s
#      0     0   43.67005    0   15   47.27128   43.67005  7.62%     -    0s
#      0     0   43.67005    0   17   47.27128   43.67005  7.62%     -    0s
#      0     0   43.67005    0   17   47.27128   43.67005  7.62%     -    0s
#      0     0   43.67005    0   18   47.27128   43.67005  7.62%     -    0s
#      0     0   43.67005    0   16   47.27128   43.67005  7.62%     -    0s
# H    0     0                      45.1973119   43.67005  3.38%     -    0s
#      0     0   43.67005    0   15   45.19731   43.67005  3.38%     -    0s
#      0     0   43.67005    0    8   45.19731   43.67005  3.38%     -    0s
# H    0     0                      45.0162950   43.67005  2.99%     -    0s
#      0     0   43.67005    0   18   45.01630   43.67005  2.99%     -    0s
#      0     0   43.67005    0   18   45.01630   43.67005  2.99%     -    0s
#      0     0   43.67083    0   10   45.01630   43.67083  2.99%     -    0s
#      0     0   43.91567    0   20   45.01630   43.91567  2.44%     -    0s
#      0     0   43.91688    0   20   45.01630   43.91688  2.44%     -    0s
#      0     0   44.70995    0   22   45.01630   44.70995  0.68%     -    0s
#      0     0   45.01630    0   22   45.01630   45.01630  0.00%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Gomory: 1
#   MIR: 7
#   Zero half: 1
#   RLT: 7
#
# Explored 1 nodes (428 simplex iterations) in 0.25 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 45.0163 45.1973 47.2713 ... 78.5164
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.501629501082e+01, best bound 4.501629501082e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,2]            1
#      x[1,16]            1
#       x[2,1]            1
#     x[11,15]            1
#     x[12,11]            1
#      x[15,0]            1
#     x[16,12]            1
#         c[0]           20
#         c[1]           24
#         c[2]           23
#        c[11]           20
#        c[12]           23
#        c[15]           19
#        c[16]           25
#        d[11]            1
#        d[12]            3
#        d[15]            1
#        d[16]            2
#         p[0]            3
#         p[1]            1
#         p[2]            1
#         z[1]            2
#         z[2]            1
#        z[11]            5
#        z[12]            4
#        z[15]            6
#        z[16]            3
#            B           12
#            D      6.50815
#            V            7
#        d_sum            7
#        p_sum            5
# 7/10/19 12:00
# threshold
# 3
# 7/10/19 13:00
# [25. 20. 15. 15. 13.  8. 14.  9.  7.  8.  6.  4.  4.  4.  2.  2.  4.  4.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6655 nonzeros
# Model fingerprint: 0xdb1f7864
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 202 rows and 33 columns
# Presolve time: 0.01s
# Presolved: 934 rows, 368 columns, 4824 nonzeros
# Variable types: 17 continuous, 351 integer (306 binary)
#
# Root relaxation: objective 5.973842e+01, 45 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   59.73842    0   12          -   59.73842      -     -    0s
# H    0     0                     102.0838690   59.73842  41.5%     -    0s
# H    0     0                      69.5609561   59.73842  14.1%     -    0s
#      0     0   62.61992    0   14   69.56096   62.61992  10.0%     -    0s
#      0     0   62.61992    0   16   69.56096   62.61992  10.0%     -    0s
# H    0     0                      68.7488704   62.61992  8.91%     -    0s
#      0     0   62.61992    0   17   68.74887   62.61992  8.91%     -    0s
#      0     0   62.61992    0   13   68.74887   62.61992  8.91%     -    0s
#      0     0   62.61992    0   19   68.74887   62.61992  8.91%     -    0s
#      0     0   62.62676    0   23   68.74887   62.62676  8.91%     -    0s
#      0     0   63.40271    0   17   68.74887   63.40271  7.78%     -    0s
#      0     0   63.40271    0   18   68.74887   63.40271  7.78%     -    0s
#      0     0   63.92453    0   20   68.74887   63.92453  7.02%     -    0s
# H    0     0                      68.6822332   64.06921  6.72%     -    0s
#      0     0   64.06921    0   21   68.68223   64.06921  6.72%     -    0s
# H    0     0                      66.5905249   64.12546  3.70%     -    0s
#      0     0   64.12729    0   26   66.59052   64.12729  3.70%     -    0s
#      0     0   64.12729    0   18   66.59052   64.12729  3.70%     -    0s
#      0     0   64.12729    0   22   66.59052   64.12729  3.70%     -    0s
#      0     0   64.12729    0   19   66.59052   64.12729  3.70%     -    0s
#      0     0   64.12729    0   28   66.59052   64.12729  3.70%     -    0s
#      0     0   64.12729    0   27   66.59052   64.12729  3.70%     -    0s
#      0     0   64.12729    0   27   66.59052   64.12729  3.70%     -    0s
#      0     0   64.12729    0   22   66.59052   64.12729  3.70%     -    0s
# H    0     0                      66.3292822   64.12729  3.32%     -    0s
#      0     0   64.12729    0   25   66.32928   64.12729  3.32%     -    0s
#      0     0   64.12729    0   25   66.32928   64.12729  3.32%     -    0s
#      0     0   64.12729    0   22   66.32928   64.12729  3.32%     -    0s
#      0     0   64.12729    0   14   66.32928   64.12729  3.32%     -    0s
#      0     0   64.59052    0   14   66.32928   64.59052  2.62%     -    0s
#      0     0   64.96687    0   14   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   15   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   27   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   20   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   22   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   18   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   18   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   19   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   26   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   29   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   29   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   20   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   27   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   26   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   20   66.32928   64.96687  2.05%     -    0s
#      0     0   64.96687    0   20   66.32928   64.96687  2.05%     -    0s
# H    0     0                      66.0577568   65.38837  1.01%     -    0s
#      0     0   65.45049    0   21   66.05776   65.45049  0.92%     -    0s
#      0     0   66.05776    0   21   66.05776   66.05776  0.00%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Implied bound: 2
#   MIR: 12
#   Inf proof: 1
#   Zero half: 1
#   RLT: 11
#
# Explored 1 nodes (750 simplex iterations) in 0.37 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 66.0578 66.3293 66.5905 ... 102.084
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.605775677411e+01, best bound 6.605775677411e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,6]            1
#      x[1,14]            1
#       x[3,1]            1
#      x[6,10]            1
#     x[10,15]            1
#      x[11,3]            1
#      x[14,0]            1
#     x[15,11]            1
#         c[0]           20
#         c[1]           22
#         c[3]           20
#         c[6]           25
#        c[10]           26
#        c[11]           23
#        c[14]           25
#        c[15]           25
#        d[10]            1
#        d[11]            3
#        d[14]            2
#        d[15]            2
#         p[0]            5
#         p[1]            3
#         p[3]            2
#         p[6]            1
#         z[1]            6
#         z[3]            5
#         z[6]            1
#        z[10]            2
#        z[11]            4
#        z[14]            7
#        z[15]            3
#            B           19
#            D      7.18592
#            V            8
#        d_sum            8
#        p_sum           11
# 7/10/19 13:00
# threshold
# 3
# 7/10/19 14:00
# [22. 19. 13. 14. 15.  9. 14.  9.  7.  6.  7.  8.  3.  2.  3.  4.  3.  2.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6658 nonzeros
# Model fingerprint: 0xce1e3fa2
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 211 rows and 35 columns
# Presolve time: 0.01s
# Presolved: 925 rows, 366 columns, 4543 nonzeros
# Variable types: 17 continuous, 349 integer (306 binary)
#
# Root relaxation: objective 6.320034e+01, 79 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   63.20034    0   19          -   63.20034      -     -    0s
#      0     0   64.09579    0   21          -   64.09579      -     -    0s
# H    0     0                     113.6409457   64.09579  43.6%     -    0s
# H    0     0                     110.6409457   64.09579  42.1%     -    0s
#      0     0   64.46610    0   20  110.64095   64.46610  41.7%     -    0s
#      0     0   64.46610    0   20  110.64095   64.46610  41.7%     -    0s
#      0     0   64.46610    0   21  110.64095   64.46610  41.7%     -    0s
#      0     0   64.46610    0   22  110.64095   64.46610  41.7%     -    0s
#      0     0   64.46610    0   26  110.64095   64.46610  41.7%     -    0s
# H    0     0                      83.7778733   64.46610  23.1%     -    0s
#      0     0   64.46610    0   27   83.77787   64.46610  23.1%     -    0s
#      0     0   64.46610    0   27   83.77787   64.46610  23.1%     -    0s
# H    0     0                      75.5645625   64.46610  14.7%     -    0s
#      0     0   64.46610    0   28   75.56456   64.46610  14.7%     -    0s
#      0     0   64.46610    0   28   75.56456   64.46610  14.7%     -    0s
# H    0     0                      73.1556101   64.48098  11.9%     -    0s
#      0     0   64.48098    0   19   73.15561   64.48098  11.9%     -    0s
# H    0     0                      71.9580059   64.48098  10.4%     -    0s
#      0     0   64.48098    0   29   71.95801   64.48098  10.4%     -    0s
#      0     0   64.48098    0   29   71.95801   64.48098  10.4%     -    0s
#      0     0   64.48098    0   27   71.95801   64.48098  10.4%     -    0s
#      0     0   64.48098    0   20   71.95801   64.48098  10.4%     -    0s
#      0     0   64.48098    0   27   71.95801   64.48098  10.4%     -    0s
#      0     0   64.48098    0   26   71.95801   64.48098  10.4%     -    0s
# H    0     0                      71.2447171   64.84347  8.98%     -    0s
#      0     0   64.95803    0   27   71.24472   64.95803  8.82%     -    0s
#      0     0   65.03140    0   25   71.24472   65.03140  8.72%     -    0s
#      0     0   65.43254    0   23   71.24472   65.43254  8.16%     -    0s
#      0     0   65.45459    0   24   71.24472   65.45459  8.13%     -    0s
# H    0     0                      70.9175830   65.60143  7.50%     -    0s
#      0     0   65.79325    0   27   70.91758   65.79325  7.23%     -    0s
#      0     0   65.79407    0   21   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   19   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   24   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   25   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   23   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   26   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   26   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   28   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   26   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   26   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   26   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   27   70.91758   65.79407  7.22%     -    0s
#      0     0   65.79407    0   24   70.91758   65.79407  7.22%     -    0s
#      0     2   65.79407    0   24   70.91758   65.79407  7.22%     -    0s
# *  394   246              16      69.9145719   65.79407  5.89%   7.8    0s
# *  409   254              20      69.7908622   65.79407  5.73%   8.0    0s
# *  504   288              38      68.8887908   65.79407  4.49%   7.6    0s
# * 1518   275              16      68.4279122   66.29238  3.12%   7.8    0s
#
# Cutting planes:
#   Learned: 10
#   Gomory: 2
#   Implied bound: 6
#   MIR: 46
#   StrongCG: 7
#   Inf proof: 3
#   Zero half: 1
#   Mod-K: 1
#   RLT: 19
#   Relax-and-lift: 6
#
# Explored 2146 nodes (18061 simplex iterations) in 0.78 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 68.4279 68.8888 69.7909 ... 83.7779
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.842791217306e+01, best bound 6.842791217306e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,6]            1
#      x[1,16]            1
#      x[3,12]            1
#       x[4,0]            1
#      x[6,17]            1
#      x[9,13]            1
#      x[12,4]            1
#     x[13,14]            1
#      x[14,1]            1
#      x[16,3]            1
#      x[17,9]            1
#         c[0]           20
#         c[1]           17
#         c[3]           18
#         c[4]           18
#         c[6]           22
#         c[9]           21
#        c[12]           19
#        c[13]           20
#        c[14]           18
#        c[16]           19
#        c[17]           23
#         d[9]            1
#        d[12]            1
#        d[13]            2
#        d[14]            1
#        d[16]            1
#        d[17]            2
#         p[0]            2
#         p[1]            2
#         p[3]            1
#         p[4]            2
#         p[6]            1
#         z[1]            6
#         z[3]            8
#         z[4]           10
#         z[6]            1
#         z[9]            3
#        z[12]            9
#        z[13]            4
#        z[14]            5
#        z[16]            7
#        z[17]            2
#            B           16
#            D      7.47597
#            V           11
#        d_sum            8
#        p_sum            8
# 7/10/19 14:00
# threshold
# 3
# 7/10/19 15:00
# [21. 17. 14. 14. 13.  8. 13. 10.  8.  8.  9.  8.  4.  4.  7.  4.  4.  2.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6650 nonzeros
# Model fingerprint: 0xa030695c
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 187 rows and 27 columns
# Presolve time: 0.01s
# Presolved: 949 rows, 374 columns, 5383 nonzeros
# Variable types: 17 continuous, 357 integer (306 binary)
# Found heuristic solution: objective 27.0490928
#
# Root relaxation: objective 1.906140e+01, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   19.06140    0    9   27.04909   19.06140  29.5%     -    0s
#      0     0   19.69152    0    8   27.04909   19.69152  27.2%     -    0s
# H    0     0                      21.0490928   19.69152  6.45%     -    0s
#      0     0   21.04909    0    7   21.04909   21.04909  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Implied bound: 1
#   MIR: 6
#   Zero half: 2
#   RLT: 4
#
# Explored 1 nodes (38 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 21.0491 27.0491
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.104909278114e+01, best bound 2.104909278114e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,3]            1
#      x[3,17]            1
#      x[17,0]            1
#         c[0]           20
#         c[3]           21
#        c[17]           22
#        d[17]            2
#         p[0]            1
#         p[3]            1
#         z[3]            1
#        z[17]            2
#            B            4
#            D      4.52455
#            V            3
#        d_sum            2
#        p_sum            2
# 7/10/19 15:00
# threshold
# 3
# 7/10/19 16:00
# [19. 16. 12. 14. 11.  9. 12. 11.  7.  9.  9.  7.  4.  4.  5.  3.  2.  4.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6651 nonzeros
# Model fingerprint: 0xbc1c06d2
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 190 rows and 28 columns
# Presolve time: 0.01s
# Presolved: 946 rows, 373 columns, 5278 nonzeros
# Variable types: 17 continuous, 356 integer (306 binary)
# Found heuristic solution: objective 65.8980893
#
# Root relaxation: objective 1.883896e+01, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   18.83896    0    6   65.89809   18.83896  71.4%     -    0s
# H    0     0                      51.1084130   18.83896  63.1%     -    0s
# H    0     0                      28.4416869   18.83896  33.8%     -    0s
#      0     0   22.76067    0    7   28.44169   22.76067  20.0%     -    0s
# H    0     0                      24.9416869   22.76067  8.74%     -    0s
#      0     0   22.76067    0    7   24.94169   22.76067  8.74%     -    0s
#      0     0   22.76067    0    6   24.94169   22.76067  8.74%     -    0s
#      0     0   22.76067    0    6   24.94169   22.76067  8.74%     -    0s
#      0     0   22.76067    0    8   24.94169   22.76067  8.74%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 2
#   MIR: 2
#   Mod-K: 1
#   RLT: 4
#
# Explored 1 nodes (67 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 24.9417 28.4417 51.1084 65.8981
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.494168685216e+01, best bound 2.494168685216e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,15]            1
#       x[3,0]            1
#     x[15,16]            1
#      x[16,3]            1
#         c[0]           20
#         c[3]           17
#        c[15]           20
#        c[16]           19
#        d[15]            1
#        d[16]            2
#         p[3]            1
#         z[3]            3
#        z[15]            1
#        z[16]            2
#            B            4
#            D      5.47084
#            V            4
#        d_sum            3
#        p_sum            1
# 7/10/19 16:00
# threshold
# 3
# 7/10/19 17:00
# [16. 17. 11. 11. 11.  9. 11. 12.  8.  9.  9.  5.  3.  1.  4.  4.  1.  4.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6652 nonzeros
# Model fingerprint: 0x09f0bffe
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 193 rows and 29 columns
# Presolve time: 0.01s
# Presolved: 943 rows, 372 columns, 5173 nonzeros
# Variable types: 17 continuous, 355 integer (306 binary)
# Found heuristic solution: objective 58.4137794
#
# Root relaxation: objective 3.053004e+01, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   30.53004    0    7   58.41378   30.53004  47.7%     -    0s
# H    0     0                      57.7444569   30.53004  47.1%     -    0s
# H    0     0                      35.1455769   30.53004  13.1%     -    0s
#      0     0   31.55193    0    6   35.14558   31.55193  10.2%     -    0s
#      0     0   31.55193    0    9   35.14558   31.55193  10.2%     -    0s
#      0     0   31.55193    0    6   35.14558   31.55193  10.2%     -    0s
#      0     0   32.68470    0    9   35.14558   32.68470  7.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 1
#   Implied bound: 1
#   MIR: 6
#   Mod-K: 2
#   RLT: 7
#   Relax-and-lift: 2
#
# Explored 1 nodes (85 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 35.1456 57.7445 58.4138
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.514557685546e+01, best bound 3.514557685546e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,12]            1
#     x[11,13]            1
#     x[12,16]            1
#      x[13,0]            1
#     x[16,11]            1
#         c[0]           20
#        c[11]           16
#        c[12]           20
#        c[13]           14
#        c[16]           19
#        d[11]            2
#        d[12]            1
#        d[13]            3
#        d[16]            3
#        z[11]            3
#        z[12]            1
#        z[13]            4
#        z[16]            2
#            B            9
#            D      3.88186
#            V            5
#        d_sum            9
# 7/10/19 17:00
# threshold
# 3
# 7/10/19 18:00
# [17. 19. 11. 13.  9.  9. 13. 12.  7. 10.  7.  5.  3.  4.  2.  4.  6.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6652 nonzeros
# Model fingerprint: 0x6225de2a
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 193 rows and 29 columns
# Presolve time: 0.01s
# Presolved: 943 rows, 372 columns, 5173 nonzeros
# Variable types: 17 continuous, 355 integer (306 binary)
# Found heuristic solution: objective 48.4351897
#
# Root relaxation: objective 2.446794e+01, 29 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   24.46794    0    8   48.43519   24.46794  49.5%     -    0s
# H    0     0                      37.0890371   24.46794  34.0%     -    0s
#      0     0   27.64913    0    8   37.08904   27.64913  25.5%     -    0s
# H    0     0                      35.2036530   27.64913  21.5%     -    0s
# H    0     0                      33.7036530   27.64913  18.0%     -    0s
#      0     0   27.64913    0    6   33.70365   27.64913  18.0%     -    0s
#      0     0   27.64913    0    9   33.70365   27.64913  18.0%     -    0s
# H    0     0                      31.0125393   27.64913  10.8%     -    0s
#      0     0   27.64913    0    9   31.01254   27.64913  10.8%     -    0s
#      0     0   27.64913    0    9   31.01254   27.64913  10.8%     -    0s
#      0     0   27.64913    0    9   31.01254   27.64913  10.8%     -    0s
#      0     0   31.01254    0   11   31.01254   31.01254  0.00%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Implied bound: 1
#   MIR: 4
#   RLT: 2
#
# Explored 1 nodes (100 simplex iterations) in 0.09 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 31.0125 33.7037 35.2037 ... 48.4352
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.101253931564e+01, best bound 3.101253931564e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,14]            1
#      x[1,12]            1
#      x[11,0]            1
#     x[12,11]            1
#      x[14,1]            1
#         c[0]           20
#         c[1]           18
#        c[11]           19
#        c[12]           20
#        c[14]           20
#        d[11]            2
#        d[12]            1
#        d[14]            2
#         p[1]            2
#         z[1]            2
#        z[11]            4
#        z[12]            3
#        z[14]            1
#            B            7
#            D      3.50418
#            V            5
#        d_sum            5
#        p_sum            2
# 7/10/19 18:00
# threshold
# 3
# 7/10/19 19:00
# [20. 18. 10. 11.  9.  9. 12. 13.  8. 10.  7.  5.  3.  1.  3.  4.  3.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6655 nonzeros
# Model fingerprint: 0x066b99ac
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 202 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 934 rows, 369 columns, 4858 nonzeros
# Variable types: 17 continuous, 352 integer (306 binary)
# Found heuristic solution: objective 72.4166866
#
# Root relaxation: objective 4.354152e+01, 43 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   43.54152    0   13   72.41669   43.54152  39.9%     -    0s
# H    0     0                      65.1983379   43.54152  33.2%     -    0s
#      0     0   44.28068    0   20   65.19834   44.28068  32.1%     -    0s
# H    0     0                      60.0653491   44.28068  26.3%     -    0s
# H    0     0                      52.5653491   44.28068  15.8%     -    0s
#      0     0   44.64239    0   18   52.56535   44.64239  15.1%     -    0s
# H    0     0                      50.9465609   44.64239  12.4%     -    0s
#      0     0   44.70475    0   16   50.94656   44.70475  12.3%     -    0s
#      0     0   44.70475    0   14   50.94656   44.70475  12.3%     -    0s
#      0     0   44.70475    0   18   50.94656   44.70475  12.3%     -    0s
#      0     0   44.70475    0   18   50.94656   44.70475  12.3%     -    0s
#      0     0   44.70475    0   19   50.94656   44.70475  12.3%     -    0s
#      0     0   44.70475    0   19   50.94656   44.70475  12.3%     -    0s
#      0     0   44.70475    0   19   50.94656   44.70475  12.3%     -    0s
#      0     0   44.70475    0   20   50.94656   44.70475  12.3%     -    0s
#      0     0   44.70475    0   17   50.94656   44.70475  12.3%     -    0s
#      0     2   44.70475    0   16   50.94656   44.70475  12.3%     -    0s
# H   84    64                      49.4338318   44.70475  9.57%   6.2    0s
# *  114    71              15      47.1032718   44.70475  5.09%   5.9    0s
# *  189    58              11      46.6423932   44.82869  3.89%   6.4    0s
#
# Cutting planes:
#   Learned: 6
#   Gomory: 3
#   Implied bound: 4
#   MIR: 16
#   StrongCG: 8
#   Mod-K: 10
#   RLT: 10
#   Relax-and-lift: 5
#
# Explored 231 nodes (1559 simplex iterations) in 0.24 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 46.6424 47.1033 49.4338 ... 72.4167
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.664239322951e+01, best bound 4.664239322951e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,2]            1
#      x[1,16]            1
#      x[2,14]            1
#     x[11,13]            1
#     x[12,11]            1
#      x[13,0]            1
#      x[14,1]            1
#     x[16,12]            1
#         c[0]           20
#         c[1]           18
#         c[2]           20
#        c[11]           17
#        c[12]           18
#        c[13]           15
#        c[14]           19
#        c[16]           19
#         d[2]            1
#        d[11]            2
#        d[12]            1
#        d[13]            3
#        d[14]            1
#        d[16]            1
#         p[1]            1
#         z[1]            3
#         z[2]            1
#        z[11]            6
#        z[12]            5
#        z[13]            7
#        z[14]            2
#        z[16]            4
#            B           10
#            D      5.21413
#            V            8
#        d_sum            9
#        p_sum            1
# 7/10/19 19:00
# threshold
# 3
# 7/10/19 20:00
# [22. 15. 14. 11. 10.  7. 13. 15.  9. 11.  7.  8.  4.  4.  3.  4.  2.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6651 nonzeros
# Model fingerprint: 0xf51e6e3f
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 190 rows and 28 columns
# Presolve time: 0.01s
# Presolved: 946 rows, 373 columns, 5278 nonzeros
# Variable types: 17 continuous, 356 integer (306 binary)
#
# Root relaxation: objective 2.420234e+01, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   24.20234    0    9          -   24.20234      -     -    0s
# H    0     0                      45.8615643   24.20234  47.2%     -    0s
# H    0     0                      44.3615643   24.20234  45.4%     -    0s
# H    0     0                      31.7786394   24.20234  23.8%     -    0s
#      0     0   25.26435    0    7   31.77864   25.26435  20.5%     -    0s
# H    0     0                      27.2786394   25.26435  7.38%     -    0s
#      0     0   25.26435    0    7   27.27864   25.26435  7.38%     -    0s
#      0     0   25.26435    0    6   27.27864   25.26435  7.38%     -    0s
#      0     0   25.27739    0    7   27.27864   25.27739  7.34%     -    0s
#      0     0   25.28358    0    7   27.27864   25.28358  7.31%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#   Zero half: 2
#   RLT: 3
#
# Explored 1 nodes (69 simplex iterations) in 0.09 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27.2786 31.7786 44.3616 45.8616
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.727863940095e+01, best bound 2.727863940095e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,7]            1
#      x[7,14]            1
#     x[14,16]            1
#      x[16,0]            1
#         c[0]           20
#         c[7]           22
#        c[14]           24
#        c[16]           23
#        d[14]            1
#        d[16]            2
#         p[0]            2
#         p[7]            2
#         z[7]            1
#        z[14]            2
#        z[16]            3
#            B            7
#            D      4.38932
#            V            4
#        d_sum            3
#        p_sum            4
# 7/10/19 20:00

# %% [markdown]
# ## Operation time before threshold adjustment

# %%
time0
# Out:
# [41.16,
#  24.3,
#  20.55,
#  45.02,
#  66.06,
#  68.43,
#  21.05,
#  24.94,
#  35.15,
#  31.01,
#  46.64,
#  27.28]

# %%
visits0
# Out:
# [5.0, 3.0, 2.0, 7.0, 8.0, 11.0, 3.0, 4.0, 5.0, 5.0, 8.0, 4.0]

# %%
time1,visits1 = hour_rebalance1(Verdun_net_balance20190710)
# Out:
# threshold
# 3
# 7/10/19 9:00
# [21. 15. 18.  9. 10.  6. 10. 11. 10.  7.  8.  8.  4.  6.  7.  3.  4.  3.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6652 nonzeros
# Model fingerprint: 0x3a019bc0
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 193 rows and 29 columns
# Presolve time: 0.01s
# Presolved: 943 rows, 372 columns, 5173 nonzeros
# Variable types: 17 continuous, 355 integer (306 binary)
#
# Root relaxation: objective 3.478785e+01, 37 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   34.78785    0   12          -   34.78785      -     -    0s
# H    0     0                      67.6282178   34.78785  48.6%     -    0s
# H    0     0                      61.3372815   34.78785  43.3%     -    0s
# H    0     0                      58.9021491   34.78785  40.9%     -    0s
#      0     0   36.75525    0   14   58.90215   36.75525  37.6%     -    0s
# H    0     0                      51.4021491   36.75525  28.5%     -    0s
#      0     0   36.75525    0   13   51.40215   36.75525  28.5%     -    0s
# H    0     0                      44.6579330   36.75525  17.7%     -    0s
#      0     0   38.69300    0   14   44.65793   38.69300  13.4%     -    0s
#      0     0   38.78965    0   13   44.65793   38.78965  13.1%     -    0s
#      0     0   38.78965    0   14   44.65793   38.78965  13.1%     -    0s
# H    0     0                      43.3372815   38.78965  10.5%     -    0s
#      0     0   38.88641    0    9   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   12   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   16   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   18   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   11   43.33728   38.88641  10.3%     -    0s
#      0     0   38.88641    0   10   43.33728   38.88641  10.3%     -    0s
# H    0     0                      41.1579330   38.88641  5.52%     -    0s
#      0     0   38.88641    0    8   41.15793   38.88641  5.52%     -    0s
#      0     0     cutoff    0        41.15793   41.15793  0.00%     -    0s
#
# Explored 1 nodes (200 simplex iterations) in 0.15 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 41.1579 43.3373 44.6579 ... 67.6282
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.115793298673e+01, best bound 4.115793298673e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,5]            1
#      x[2,17]            1
#       x[5,2]            1
#      x[15,0]            1
#     x[17,15]            1
#         c[0]           20
#         c[2]           20
#         c[5]           21
#        c[15]           20
#        c[17]           21
#         d[5]            1
#        d[15]            1
#        d[17]            1
#         p[0]            1
#         p[2]            1
#         z[2]            2
#         z[5]            1
#        z[15]            4
#        z[17]            3
#            B            5
#            D      7.88598
#            V            5
#        d_sum            3
#        p_sum            2
# 7/10/19 9:00
# threshold
# 2
# 7/10/19 10:00
# [21. 13. 17. 11. 10.  7. 10. 10. 10.  6.  8.  8.  1.  6.  6.  4.  4.  4.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6655 nonzeros
# Model fingerprint: 0x2d244109
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 202 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 934 rows, 369 columns, 4858 nonzeros
# Variable types: 17 continuous, 352 integer (306 binary)
#
# Root relaxation: objective 4.588858e+01, 36 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.88858    0   10          -   45.88858      -     -    0s
# H    0     0                      97.9540542   45.88858  53.2%     -    0s
# H    0     0                      65.6390448   45.88858  30.1%     -    0s
# H    0     0                      65.4856887   45.88858  29.9%     -    0s
#      0     0   48.33980    0   15   65.48569   48.33980  26.2%     -    0s
# H    0     0                      59.0717866   48.33980  18.2%     -    0s
#      0     0   48.33980    0   16   59.07179   48.33980  18.2%     -    0s
#      0     0   48.33980    0   21   59.07179   48.33980  18.2%     -    0s
# H    0     0                      57.9690125   49.09298  15.3%     -    0s
#      0     0   49.15902    0   20   57.96901   49.15902  15.2%     -    0s
#      0     0   49.30646    0   22   57.96901   49.30646  14.9%     -    0s
#      0     0   49.79236    0   16   57.96901   49.79236  14.1%     -    0s
#      0     0   49.98244    0   16   57.96901   49.98244  13.8%     -    0s
# H    0     0                      57.8525513   50.40383  12.9%     -    0s
#      0     0   50.40383    0   18   57.85255   50.40383  12.9%     -    0s
#      0     0   50.48030    0   17   57.85255   50.48030  12.7%     -    0s
#      0     0   50.48030    0   10   57.85255   50.48030  12.7%     -    0s
#      0     0   50.48030    0   16   57.85255   50.48030  12.7%     -    0s
#      0     0   50.48030    0   21   57.85255   50.48030  12.7%     -    0s
#      0     0   50.48030    0   18   57.85255   50.48030  12.7%     -    0s
#      0     0   50.48030    0    6   57.85255   50.48030  12.7%     -    0s
#      0     0   50.48030    0   14   57.85255   50.48030  12.7%     -    0s
#      0     0   50.48030    0   14   57.85255   50.48030  12.7%     -    0s
#      0     0   50.48030    0   15   57.85255   50.48030  12.7%     -    0s
# H    0     0                      56.5687602   50.48030  10.8%     -    0s
#      0     0   50.48030    0   15   56.56876   50.48030  10.8%     -    0s
#      0     0   50.48030    0   14   56.56876   50.48030  10.8%     -    0s
# H    0     0                      54.8876651   50.52685  7.94%     -    0s
#      0     0   50.53180    0   14   54.88767   50.53180  7.94%     -    0s
#      0     0   50.53180    0   13   54.88767   50.53180  7.94%     -    0s
#      0     0   50.53180    0   18   54.88767   50.53180  7.94%     -    0s
#      0     0   50.53180    0   15   54.88767   50.53180  7.94%     -    0s
#      0     0   50.53180    0   19   54.88767   50.53180  7.94%     -    0s
#      0     0   50.53180    0   16   54.88767   50.53180  7.94%     -    0s
# H    0     0                      54.5698163   50.53180  7.40%     -    0s
#      0     0   50.53180    0   15   54.56982   50.53180  7.40%     -    0s
# H    0     0                      53.2979343   50.53180  5.19%     -    0s
#      0     0   50.53180    0   11   53.29793   50.53180  5.19%     -    0s
#      0     0   50.53180    0   10   53.29793   50.53180  5.19%     -    0s
#      0     0   50.53180    0   10   53.29793   50.53180  5.19%     -    0s
#      0     0   50.53180    0   14   53.29793   50.53180  5.19%     -    0s
#      0     0   50.53180    0   15   53.29793   50.53180  5.19%     -    0s
# H    0     0                      52.3319919   50.61305  3.28%     -    0s
#      0     0   50.62366    0   19   52.33199   50.62366  3.26%     -    0s
#      0     0   50.62366    0   10   52.33199   50.62366  3.26%     -    0s
#      0     0   50.62366    0   20   52.33199   50.62366  3.26%     -    0s
#      0     0   50.62366    0   18   52.33199   50.62366  3.26%     -    0s
#      0     0   50.62366    0   21   52.33199   50.62366  3.26%     -    0s
#      0     0   50.62366    0   19   52.33199   50.62366  3.26%     -    0s
#      0     0   50.62366    0   20   52.33199   50.62366  3.26%     -    0s
#      0     0   50.62366    0   22   52.33199   50.62366  3.26%     -    0s
#      0     0   50.62366    0   21   52.33199   50.62366  3.26%     -    0s
#      0     0   50.79001    0   14   52.33199   50.79001  2.95%     -    0s
#      0     0   50.96603    0   18   52.33199   50.96603  2.61%     -    0s
#      0     0   51.11692    0   19   52.33199   51.11692  2.32%     -    0s
#      0     0   51.54384    0   16   52.33199   51.54384  1.51%     -    0s
#      0     0   52.33199    0   19   52.33199   52.33199  0.00%     -    0s
#
# Cutting planes:
#   Learned: 2
#   Cover: 1
#   Implied bound: 1
#   MIR: 9
#   StrongCG: 1
#   Inf proof: 1
#   RLT: 4
#
# Explored 1 nodes (769 simplex iterations) in 0.59 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 52.332 53.2979 54.5698 ... 65.639
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.233199194725e+01, best bound 5.233199194725e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,12]            1
#      x[2,17]            1
#      x[5,16]            1
#      x[9,15]            1
#      x[12,5]            1
#      x[15,0]            1
#      x[16,2]            1
#      x[17,9]            1
#         c[0]           20
#         c[2]           16
#         c[5]           18
#         c[9]           16
#        c[12]           22
#        c[15]           14
#        c[16]           17
#        c[17]           17
#         d[5]            1
#         d[9]            2
#        d[12]            4
#        d[15]            1
#        d[16]            1
#        d[17]            1
#         p[0]            2
#         p[2]            1
#         z[2]            4
#         z[5]            2
#         z[9]            6
#        z[12]            1
#        z[15]            7
#        z[16]            3
#        z[17]            5
#            B           13
#            D        8.416
#            V            8
#        d_sum           10
#        p_sum            3
# 7/10/19 10:00
# threshold
# 2
# 7/10/19 11:00
# [23. 17. 15. 12. 10. 10. 12. 10.  9.  9.  8.  7.  5.  4.  6.  5.  2.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6652 nonzeros
# Model fingerprint: 0x32e5da06
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 193 rows and 29 columns
# Presolve time: 0.01s
# Presolved: 943 rows, 372 columns, 5173 nonzeros
# Variable types: 17 continuous, 355 integer (306 binary)
#
# Root relaxation: objective 2.997080e+01, 22 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   29.97080    0    4          -   29.97080      -     -    0s
# H    0     0                      48.3411250   29.97080  38.0%     -    0s
# H    0     0                      45.7845880   29.97080  34.5%     -    0s
# H    0     0                      41.5191911   29.97080  27.8%     -    0s
#      0     0   31.55602    0    8   41.51919   31.55602  24.0%     -    0s
# H    0     0                      38.8161750   31.55602  18.7%     -    0s
#      0     0   31.55602    0   10   38.81618   31.55602  18.7%     -    0s
# H    0     0                      33.8632760   31.55602  6.81%     -    0s
#      0     0   32.91355    0   12   33.86328   32.91355  2.80%     -    0s
#      0     0   32.91355    0   10   33.86328   32.91355  2.80%     -    0s
#      0     0   32.91355    0   10   33.86328   32.91355  2.80%     -    0s
#      0     0   33.86328    0   11   33.86328   33.86328  0.00%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Implied bound: 1
#   MIR: 3
#   RLT: 3
#
# Explored 1 nodes (85 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 33.8633 38.8162 41.5192 ... 48.3411
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.386327603016e+01, best bound 3.386327603016e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,13]            1
#      x[1,16]            1
#      x[11,0]            1
#      x[13,1]            1
#     x[16,11]            1
#         c[0]           20
#         c[1]           23
#        c[11]           21
#        c[13]           24
#        c[16]           24
#        d[11]            1
#        d[13]            1
#        d[16]            3
#         p[0]            4
#         p[1]            1
#         z[1]            2
#        z[11]            4
#        z[13]            1
#        z[16]            3
#            B           10
#            D      4.43164
#            V            5
#        d_sum            5
#        p_sum            5
# 7/10/19 11:00
# threshold
# 2
# 7/10/19 12:00
# [22. 17. 17. 13. 12.  8. 12. 10.  7.  9.  9.  7.  2.  5.  6.  4.  3.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6656 nonzeros
# Model fingerprint: 0x86ce4aac
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 205 rows and 33 columns
# Presolve time: 0.01s
# Presolved: 931 rows, 368 columns, 4753 nonzeros
# Variable types: 17 continuous, 351 integer (306 binary)
#
# Root relaxation: objective 5.294962e+01, 52 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   52.94962    0   15          -   52.94962      -     -    0s
# H    0     0                     159.1104272   52.94962  66.7%     -    0s
# H    0     0                     111.1861563   52.94962  52.4%     -    0s
#      0     0   57.50038    0   15  111.18616   57.50038  48.3%     -    0s
# H    0     0                      80.6920384   57.50038  28.7%     -    0s
# H    0     0                      73.1920384   57.50038  21.4%     -    0s
#      0     0   57.50038    0   16   73.19204   57.50038  21.4%     -    0s
#      0     0   57.54565    0   23   73.19204   57.54565  21.4%     -    0s
#      0     0   57.54565    0   23   73.19204   57.54565  21.4%     -    0s
#      0     0   57.54565    0   21   73.19204   57.54565  21.4%     -    0s
#      0     0   57.54565    0   21   73.19204   57.54565  21.4%     -    0s
# H    0     0                      62.2486681   57.54565  7.56%     -    0s
#      0     0   57.63150    0   22   62.24867   57.63150  7.42%     -    0s
#      0     0   57.63150    0   15   62.24867   57.63150  7.42%     -    0s
#      0     0   57.63150    0   23   62.24867   57.63150  7.42%     -    0s
#      0     0   57.63150    0   17   62.24867   57.63150  7.42%     -    0s
#      0     0   57.63150    0   20   62.24867   57.63150  7.42%     -    0s
#      0     0   57.63150    0   21   62.24867   57.63150  7.42%     -    0s
#      0     0   57.63150    0   24   62.24867   57.63150  7.42%     -    0s
#      0     0   57.63150    0   23   62.24867   57.63150  7.42%     -    0s
#      0     0   57.66008    0   20   62.24867   57.66008  7.37%     -    0s
#      0     0   57.91945    0   17   62.24867   57.91945  6.95%     -    0s
#      0     0   57.91945    0   17   62.24867   57.91945  6.95%     -    0s
#      0     2   57.91945    0   17   62.24867   57.91945  6.95%     -    0s
# *  220   142              43      60.6489372   57.91945  4.50%   6.8    0s
# *  250   150              30      60.6353022   57.91945  4.48%   6.5    0s
# *  290   148              18      59.7266689   57.91945  3.03%   6.7    0s
#
# Cutting planes:
#   Learned: 4
#   Gomory: 2
#   Implied bound: 5
#   MIR: 35
#   StrongCG: 4
#   RLT: 19
#   Relax-and-lift: 3
#
# Explored 550 nodes (3757 simplex iterations) in 0.36 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 59.7267 60.6353 60.6489 ... 159.11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.972666891516e+01, best bound 5.972666891516e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,11]            1
#       x[1,2]            1
#       x[2,8]            1
#      x[3,16]            1
#      x[8,15]            1
#     x[11,12]            1
#      x[12,3]            1
#      x[15,0]            1
#      x[16,1]            1
#         c[0]           20
#         c[1]           18
#         c[2]           19
#         c[3]           19
#         c[8]           20
#        c[11]           23
#        c[12]           22
#        c[15]           19
#        c[16]           20
#         d[8]            1
#        d[11]            1
#        d[12]            3
#        d[15]            1
#        d[16]            2
#         p[0]            3
#         p[1]            1
#         p[2]            1
#         p[3]            1
#         z[1]            5
#         z[2]            6
#         z[3]            3
#         z[8]            7
#        z[11]            1
#        z[12]            2
#        z[15]            8
#        z[16]            4
#            B           14
#            D      10.3633
#            V            9
#        d_sum            8
#        p_sum            6
# 7/10/19 12:00
# threshold
# 4
# 7/10/19 13:00
# [24. 19. 14. 14. 13.  9. 14.  9.  8.  9.  6.  5.  5.  5.  2.  3.  5.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6651 nonzeros
# Model fingerprint: 0x29a7213b
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 190 rows and 28 columns
# Presolve time: 0.01s
# Presolved: 946 rows, 373 columns, 5278 nonzeros
# Variable types: 17 continuous, 356 integer (309 binary)
# Found heuristic solution: objective 49.9351897
#
# Root relaxation: objective 2.400178e+01, 16 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   24.00178    0    6   49.93519   24.00178  51.9%     -    0s
# H    0     0                      42.3651898   24.00178  43.3%     -    0s
#      0     0   24.00178    0    7   42.36519   24.00178  43.3%     -    0s
# H    0     0                      41.1143047   24.00178  41.6%     -    0s
# H    0     0                      33.2126689   24.00178  27.7%     -    0s
# H    0     0                      27.3651898   24.00178  12.3%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 5
#   Zero half: 1
#   RLT: 6
#
# Explored 1 nodes (23 simplex iterations) in 0.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 27.3652 33.2127 41.1143 ... 49.9352
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.736518976408e+01, best bound 2.736518976408e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,14]            1
#      x[1,11]            1
#      x[11,0]            1
#      x[14,1]            1
#         c[0]           20
#         c[1]           22
#        c[11]           23
#        c[14]           23
#        d[11]            1
#        d[14]            1
#         p[0]            3
#         p[1]            1
#         z[1]            2
#        z[11]            3
#        z[14]            1
#            B            6
#            D      3.45506
#            V            4
#        d_sum            2
#        p_sum            4
# 7/10/19 13:00
# threshold
# 4
# 7/10/19 14:00
# [23. 20. 12. 15. 15. 10. 15.  9.  8.  7.  6.  7.  4.  3.  2.  3.  4.  3.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6653 nonzeros
# Model fingerprint: 0xd2341611
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 196 rows and 30 columns
# Presolve time: 0.01s
# Presolved: 940 rows, 371 columns, 5068 nonzeros
# Variable types: 17 continuous, 354 integer (306 binary)
#
# Root relaxation: objective 3.360102e+01, 29 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   33.60102    0   12          -   33.60102      -     -    0s
# H    0     0                      90.2680569   33.60102  62.8%     -    0s
# H    0     0                      82.4765855   33.60102  59.3%     -    0s
# H    0     0                      53.8140921   33.60102  37.6%     -    0s
#      0     0   35.56237    0   17   53.81409   35.56237  33.9%     -    0s
# H    0     0                      40.3140921   35.56237  11.8%     -    0s
# H    0     0                      38.6668636   35.56237  8.03%     -    0s
#      0     0   35.60167    0   17   38.66686   35.60167  7.93%     -    0s
#      0     0   36.12300    0    9   38.66686   36.12300  6.58%     -    0s
#      0     0   36.12300    0   12   38.66686   36.12300  6.58%     -    0s
# H    0     0                      38.2373528   36.12300  5.53%     -    0s
#      0     0   36.12300    0    9   38.23735   36.12300  5.53%     -    0s
#      0     0   36.12300    0    9   38.23735   36.12300  5.53%     -    0s
# H    0     0                      38.1340955   36.12300  5.27%     -    0s
#      0     0   36.12300    0   15   38.13410   36.12300  5.27%     -    0s
#      0     0   36.12300    0   12   38.13410   36.12300  5.27%     -    0s
#      0     0   36.12300    0   15   38.13410   36.12300  5.27%     -    0s
#      0     0   36.12300    0   15   38.13410   36.12300  5.27%     -    0s
#      0     0   36.12300    0   15   38.13410   36.12300  5.27%     -    0s
#      0     0   36.16061    0   13   38.13410   36.16061  5.18%     -    0s
#      0     0   36.16061    0   13   38.13410   36.16061  5.18%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 2
#   MIR: 9
#   Mod-K: 1
#   RLT: 6
#   Relax-and-lift: 2
#
# Explored 1 nodes (192 simplex iterations) in 0.15 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 38.1341 38.2374 38.6669 ... 90.2681
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.813409546586e+01, best bound 3.813409546586e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,14]            1
#       x[1,3]            1
#       x[3,4]            1
#       x[4,6]            1
#       x[6,0]            1
#      x[14,1]            1
#         c[0]           20
#         c[1]           21
#         c[3]           23
#         c[4]           24
#         c[6]           25
#        c[14]           22
#        d[14]            1
#         p[0]            2
#         p[1]            2
#         p[3]            1
#         p[4]            1
#         p[6]            1
#         z[1]            2
#         z[3]            3
#         z[4]            4
#         z[6]            5
#        z[14]            1
#            B            8
#            D      4.71137
#            V            6
#        d_sum            1
#        p_sum            7
# 7/10/19 14:00
# threshold
# 4
# 7/10/19 15:00
# [22. 18. 13. 15. 14.  9. 14. 10.  9.  8.  8.  7.  4.  3.  6.  3.  4.  1.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6650 nonzeros
# Model fingerprint: 0xf5ef84c4
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 187 rows and 27 columns
# Presolve time: 0.01s
# Presolved: 949 rows, 374 columns, 5383 nonzeros
# Variable types: 17 continuous, 357 integer (308 binary)
# Found heuristic solution: objective 25.5490928
#
# Root relaxation: objective 1.906140e+01, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   19.06140    0    9   25.54909   19.06140  25.4%     -    0s
#      0     0   19.69152    0    7   25.54909   19.69152  22.9%     -    0s
#      0     0   19.69152    0    9   25.54909   19.69152  22.9%     -    0s
# H    0     0                      21.0490928   19.69152  6.45%     -    0s
#      0     0   20.27958    0    8   21.04909   20.27958  3.66%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 1
#   MIR: 2
#   RLT: 3
#
# Explored 1 nodes (74 simplex iterations) in 0.08 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 21.0491 25.5491
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.104909278114e+01, best bound 2.104909278114e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,17]            1
#       x[3,0]            1
#      x[17,3]            1
#         c[0]           20
#         c[3]           19
#        c[17]           21
#        d[17]            2
#         p[0]            1
#         p[3]            1
#         z[3]            2
#        z[17]            1
#            B            4
#            D      4.52455
#            V            3
#        d_sum            2
#        p_sum            2
# 7/10/19 15:00
# threshold
# 3
# 7/10/19 16:00
# [20. 17. 11. 15. 12. 10. 13. 11.  8.  9.  8.  6.  4.  3.  4.  2.  2.  3.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6654 nonzeros
# Model fingerprint: 0xb64921cc
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Found heuristic solution: objective 65.1971104
# Presolve removed 199 rows and 31 columns
# Presolve time: 0.01s
# Presolved: 937 rows, 370 columns, 4963 nonzeros
# Variable types: 17 continuous, 353 integer (306 binary)
#
# Root relaxation: objective 3.431342e+01, 25 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   34.31342    0   12   65.19711   34.31342  47.4%     -    0s
# H    0     0                      62.8980768   34.31342  45.4%     -    0s
# H    0     0                      61.3980768   34.31342  44.1%     -    0s
# H    0     0                      57.2968232   34.31342  40.1%     -    0s
#      0     0   34.31342    0   17   57.29682   34.31342  40.1%     -    0s
# H    0     0                      49.4185822   34.31342  30.6%     -    0s
# H    0     0                      40.4185822   34.31342  15.1%     -    0s
#      0     0   34.49106    0   15   40.41858   34.49106  14.7%     -    0s
#      0     0   34.49106    0   14   40.41858   34.49106  14.7%     -    0s
#      0     0   34.49106    0   16   40.41858   34.49106  14.7%     -    0s
#      0     0   34.49106    0   23   40.41858   34.49106  14.7%     -    0s
#      0     0   34.49106    0   23   40.41858   34.49106  14.7%     -    0s
#      0     0   36.18865    0   25   40.41858   36.18865  10.5%     -    0s
#      0     0   36.47915    0   20   40.41858   36.47915  9.75%     -    0s
#      0     0   36.47915    0   20   40.41858   36.47915  9.75%     -    0s
#      0     0   37.62465    0   17   40.41858   37.62465  6.91%     -    0s
#      0     0   37.62878    0   21   40.41858   37.62878  6.90%     -    0s
#      0     0   37.62878    0   23   40.41858   37.62878  6.90%     -    0s
# H    0     0                      40.2923467   37.81342  6.15%     -    0s
#      0     0   37.95825    0   20   40.29235   37.95825  5.79%     -    0s
#      0     0   37.95825    0   20   40.29235   37.95825  5.79%     -    0s
#      0     0   38.01118    0   21   40.29235   38.01118  5.66%     -    0s
#      0     0   38.01118    0   24   40.29235   38.01118  5.66%     -    0s
#      0     0   38.17546    0   18   40.29235   38.17546  5.25%     -    0s
#      0     0   38.29235    0   20   40.29235   38.29235  4.96%     -    0s
#      0     0   38.83483    0   19   40.29235   38.83483  3.62%     -    0s
#      0     0   40.29235    0   18   40.29235   40.29235  0.00%     -    0s
#
# Cutting planes:
#   Learned: 1
#   Gomory: 3
#   Clique: 2
#   MIR: 9
#   StrongCG: 1
#   Zero half: 1
#   RLT: 14
#   Relax-and-lift: 1
#
# Explored 1 nodes (355 simplex iterations) in 0.24 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 40.2923 40.4186 49.4186 ... 65.1971
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.029234669942e+01, best bound 4.029234669942e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,3]            1
#      x[3,16]            1
#     x[11,13]            1
#     x[13,15]            1
#     x[15,17]            1
#     x[16,11]            1
#      x[17,0]            1
#         c[0]           20
#         c[3]           20
#        c[11]           20
#        c[13]           19
#        c[15]           18
#        c[16]           22
#        c[17]           16
#        d[11]            1
#        d[13]            1
#        d[15]            2
#        d[16]            2
#        d[17]            1
#         p[3]            2
#         z[3]            1
#        z[11]            3
#        z[13]            4
#        z[15]            5
#        z[16]            2
#        z[17]            6
#            B            9
#            D      6.39617
#            V            7
#        d_sum            7
#        p_sum            2
# 7/10/19 16:00
# threshold
# 3
# 7/10/19 17:00
# [17. 18. 10. 11. 12. 10. 12. 12.  9.  9.  8.  5.  3.  1.  3.  4.  1.  4.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6655 nonzeros
# Model fingerprint: 0xf922ff56
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 202 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 934 rows, 369 columns, 4858 nonzeros
# Variable types: 17 continuous, 352 integer (306 binary)
# Found heuristic solution: objective 73.9166866
#
# Root relaxation: objective 4.654152e+01, 54 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   46.54152    0   14   73.91669   46.54152  37.0%     -    0s
# H    0     0                      67.1730676   46.54152  30.7%     -    0s
#      0     0   47.28068    0   17   67.17307   47.28068  29.6%     -    0s
# H    0     0                      60.4917027   47.28068  21.8%     -    0s
# H    0     0                      54.7965533   47.28068  13.7%     -    0s
#      0     0   47.64239    0   17   54.79655   47.64239  13.1%     -    0s
#      0     0   47.70475    0   19   54.79655   47.70475  12.9%     -    0s
#      0     0   47.70475    0   14   54.79655   47.70475  12.9%     -    0s
#      0     0   47.70475    0   20   54.79655   47.70475  12.9%     -    0s
#      0     0   47.70475    0   18   54.79655   47.70475  12.9%     -    0s
#      0     0   47.70475    0   19   54.79655   47.70475  12.9%     -    0s
# H    0     0                      50.1656293   47.70475  4.91%     -    0s
#      0     0   47.70475    0   15   50.16563   47.70475  4.91%     -    0s
#      0     0   47.70475    0   14   50.16563   47.70475  4.91%     -    0s
# H    0     0                      49.6423932   47.70475  3.90%     -    0s
#      0     0   47.70475    0   17   49.64239   47.70475  3.90%     -    0s
#      0     0   47.70475    0   17   49.64239   47.70475  3.90%     -    0s
#      0     0   47.70475    0   14   49.64239   47.70475  3.90%     -    0s
#      0     0   47.77650    0   20   49.64239   47.77650  3.76%     -    0s
#      0     0   47.92062    0   21   49.64239   47.92062  3.47%     -    0s
#      0     0   48.50938    0   20   49.64239   48.50938  2.28%     -    0s
#      0     0   48.68840    0   20   49.64239   48.68840  1.92%     -    0s
#      0     2   48.68840    0   20   49.64239   48.68840  1.92%     -    0s
#
# Cutting planes:
#   Learned: 5
#   Gomory: 2
#   MIR: 9
#   StrongCG: 1
#   RLT: 12
#   Relax-and-lift: 4
#
# Explored 88 nodes (974 simplex iterations) in 0.23 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 49.6424 50.1656 54.7966 ... 73.9167
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.964239322951e+01, best bound 4.964239322951e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,13]            1
#      x[1,14]            1
#       x[2,0]            1
#     x[11,12]            1
#     x[12,16]            1
#     x[13,11]            1
#      x[14,2]            1
#      x[16,1]            1
#         c[0]           20
#         c[1]           11
#         c[2]           11
#        c[11]           17
#        c[12]           15
#        c[13]           20
#        c[14]           12
#        c[16]           14
#         d[2]            1
#        d[11]            2
#        d[12]            1
#        d[13]            3
#        d[14]            1
#        d[16]            3
#         p[1]            1
#         z[1]            5
#         z[2]            7
#        z[11]            2
#        z[12]            3
#        z[13]            1
#        z[14]            6
#        z[16]            4
#            B           12
#            D      5.21413
#            V            8
#        d_sum           11
#        p_sum            1
# 7/10/19 17:00
# threshold
# 3
# 7/10/19 18:00
# [18. 19. 11. 13. 10. 10. 14. 12.  8. 10.  6.  5.  3.  4.  2.  4.  6.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6654 nonzeros
# Model fingerprint: 0x784d907f
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 199 rows and 31 columns
# Presolve time: 0.01s
# Presolved: 937 rows, 370 columns, 4963 nonzeros
# Variable types: 17 continuous, 353 integer (306 binary)
# Found heuristic solution: objective 85.7694253
#
# Root relaxation: objective 3.800856e+01, 43 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   38.00856    0   15   85.76943   38.00856  55.7%     -    0s
# H    0     0                      81.6353578   38.00856  53.4%     -    0s
#      0     0   43.74388    0   22   81.63536   43.74388  46.4%     -    0s
# H    0     0                      59.9294808   43.74388  27.0%     -    0s
#      0     0   43.74388    0   15   59.92948   43.74388  27.0%     -    0s
# H    0     0                      47.2509492   43.74388  7.42%     -    0s
#      0     0   44.68863    0   15   47.25095   44.68863  5.42%     -    0s
#      0     0   44.68863    0   14   47.25095   44.68863  5.42%     -    0s
#      0     0   44.68863    0   19   47.25095   44.68863  5.42%     -    0s
#      0     0   44.68863    0   15   47.25095   44.68863  5.42%     -    0s
#      0     0   44.68863    0   16   47.25095   44.68863  5.42%     -    0s
#      0     0   44.68863    0   16   47.25095   44.68863  5.42%     -    0s
#      0     0   44.68863    0   19   47.25095   44.68863  5.42%     -    0s
#      0     0   45.25095    0   23   47.25095   45.25095  4.23%     -    0s
#      0     0   45.82121    0   27   47.25095   45.82121  3.03%     -    0s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 1
#   MIR: 8
#   Inf proof: 1
#   Zero half: 3
#   RLT: 4
#
# Explored 1 nodes (252 simplex iterations) in 0.14 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 47.2509 59.9295 81.6354 85.7694
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.725094917752e+01, best bound 4.725094917752e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,10]            1
#      x[1,12]            1
#      x[6,14]            1
#      x[10,6]            1
#      x[11,0]            1
#     x[12,11]            1
#      x[14,1]            1
#         c[0]           20
#         c[1]           18
#         c[6]           19
#        c[10]           20
#        c[11]           19
#        c[12]           20
#        c[14]           20
#        d[10]            1
#        d[11]            2
#        d[12]            1
#        d[14]            2
#         p[1]            2
#         p[6]            1
#         z[1]            4
#         z[6]            2
#        z[10]            1
#        z[11]            6
#        z[12]            5
#        z[14]            3
#        z[15]         1995
#            B            9
#            D      6.58365
#            V            7
#        d_sum            6
#        p_sum            3
# 7/10/19 18:00
# threshold
# 3
# 7/10/19 19:00
# [21. 18. 10. 11. 10. 10. 12. 13.  9. 10.  7.  5.  3.  1.  3.  4.  3.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6655 nonzeros
# Model fingerprint: 0x9e59ed24
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 202 rows and 32 columns
# Presolve time: 0.01s
# Presolved: 934 rows, 369 columns, 4858 nonzeros
# Variable types: 17 continuous, 352 integer (306 binary)
# Found heuristic solution: objective 78.4166866
#
# Root relaxation: objective 4.504152e+01, 43 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   45.04152    0   13   78.41669   45.04152  42.6%     -    0s
# H    0     0                      75.4769835   45.04152  40.3%     -    0s
# H    0     0                      67.2439438   45.04152  33.0%     -    0s
#      0     0   45.78068    0   18   67.24394   45.78068  31.9%     -    0s
# H    0     0                      64.2439438   45.78068  28.7%     -    0s
#      0     0   46.14239    0   18   64.24394   46.14239  28.2%     -    0s
#      0     0   46.20475    0   15   64.24394   46.20475  28.1%     -    0s
# H    0     0                      59.5049076   46.20475  22.4%     -    0s
#      0     0   46.38171    0   21   59.50491   46.38171  22.1%     -    0s
# H    0     0                      58.0049076   46.38171  20.0%     -    0s
# H    0     0                      52.0049076   46.38171  10.8%     -    0s
#      0     0   46.42759    0   21   52.00491   46.42759  10.7%     -    0s
#      0     0   46.52761    0   20   52.00491   46.52761  10.5%     -    0s
#      0     0   46.52761    0   14   52.00491   46.52761  10.5%     -    0s
#      0     0   46.52761    0   18   52.00491   46.52761  10.5%     -    0s
# H    0     0                      48.6656293   46.52761  4.39%     -    0s
#      0     0   46.52761    0   21   48.66563   46.52761  4.39%     -    0s
#      0     0   46.52761    0   21   48.66563   46.52761  4.39%     -    0s
#      0     0   46.52761    0   24   48.66563   46.52761  4.39%     -    0s
#      0     0   46.52761    0   14   48.66563   46.52761  4.39%     -    0s
# H    0     0                      48.1423932   46.52761  3.35%     -    0s
#      0     0   46.52761    0   14   48.14239   46.52761  3.35%     -    0s
#      0     0   46.52761    0   20   48.14239   46.52761  3.35%     -    0s
#      0     0   46.52761    0   25   48.14239   46.52761  3.35%     -    0s
#      0     0   46.52761    0   22   48.14239   46.52761  3.35%     -    0s
#      0     0   46.52761    0   22   48.14239   46.52761  3.35%     -    0s
#      0     0   46.52761    0   22   48.14239   46.52761  3.35%     -    0s
#      0     0   46.52761    0   20   48.14239   46.52761  3.35%     -    0s
#      0     2   46.52761    0   18   48.14239   46.52761  3.35%     -    0s
#
# Cutting planes:
#   Learned: 5
#   Gomory: 2
#   Implied bound: 2
#   MIR: 11
#   Mod-K: 1
#   RLT: 8
#   Relax-and-lift: 1
#
# Explored 75 nodes (870 simplex iterations) in 0.26 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 48.1424 48.6656 52.0049 ... 78.4167
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.814239322951e+01, best bound 4.814239322951e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#      x[0,13]            1
#      x[1,14]            1
#       x[2,0]            1
#     x[11,12]            1
#     x[12,16]            1
#     x[13,11]            1
#      x[14,2]            1
#      x[16,1]            1
#         c[0]           20
#         c[1]           14
#         c[2]           14
#        c[11]           18
#        c[12]           16
#        c[13]           21
#        c[14]           15
#        c[16]           15
#         d[2]            1
#        d[11]            2
#        d[12]            1
#        d[13]            3
#        d[14]            1
#        d[16]            1
#         p[0]            1
#         p[1]            1
#         z[1]            5
#         z[2]            7
#        z[11]            2
#        z[12]            3
#        z[13]            1
#        z[14]            6
#        z[16]            4
#            B           11
#            D      5.21413
#            V            8
#        d_sum            9
#        p_sum            2
# 7/10/19 19:00
# threshold
# 3
# 7/10/19 20:00
# [22. 15. 14. 11. 11.  8. 13. 15. 10. 11.  7.  8.  4.  4.  3.  4.  2.  5.]
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (mac64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 1136 rows, 401 columns and 6651 nonzeros
# Model fingerprint: 0xee49e84f
# Variable types: 19 continuous, 382 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 2e+03]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 190 rows and 28 columns
# Presolve time: 0.01s
# Presolved: 946 rows, 373 columns, 5278 nonzeros
# Variable types: 17 continuous, 356 integer (306 binary)
#
# Root relaxation: objective 2.420234e+01, 28 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   24.20234    0    9          -   24.20234      -     -    0s
# H    0     0                      45.8615643   24.20234  47.2%     -    0s
# H    0     0                      44.3615643   24.20234  45.4%     -    0s
# H    0     0                      31.7786394   24.20234  23.8%     -    0s
#      0     0   25.26435    0    7   31.77864   25.26435  20.5%     -    0s
# H    0     0                      27.2786394   25.26435  7.38%     -    0s
#      0     0   25.26435    0    7   27.27864   25.26435  7.38%     -    0s
#      0     0   25.26435    0    6   27.27864   25.26435  7.38%     -    0s
#      0     0   25.27739    0    7   27.27864   25.27739  7.34%     -    0s
#      0     0   25.28358    0    7   27.27864   25.28358  7.31%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 2
#   Zero half: 2
#   RLT: 3
#
# Explored 1 nodes (69 simplex iterations) in 0.10 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 27.2786 31.7786 44.3616 45.8616
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.727863940095e+01, best bound 2.727863940095e+01, gap 0.0000%
#
#     Variable            X
# -------------------------
#       x[0,7]            1
#      x[7,14]            1
#     x[14,16]            1
#      x[16,0]            1
#         c[0]           20
#         c[7]           22
#        c[14]           24
#        c[16]           23
#        d[14]            1
#        d[16]            2
#         p[0]            2
#         p[7]            2
#         z[7]            1
#        z[14]            2
#        z[16]            3
#            B            7
#            D      4.38932
#            V            4
#        d_sum            3
#        p_sum            4
# 7/10/19 20:00

# %% [markdown]
# ## Operation time after threshold adjustment

# %%
time1
# Out:
# [41.16,
#  52.33,
#  33.86,
#  59.73,
#  27.37,
#  38.13,
#  21.05,
#  40.29,
#  49.64,
#  47.25,
#  48.14,
#  27.28]

# %%
visits1
# Out:
# [5.0, 8.0, 5.0, 9.0, 4.0, 6.0, 3.0, 7.0, 8.0, 7.0, 8.0, 4.0]

# %%
time2,visits = hour_rebalance1(Verdun_net_balance20190710)

# %%
time2

# %%
print('Operation cost for July 8th is {} dollars.'.format(daily_cost))
print('The driver travelled {} stations and rebalanced {} bikes.'.format(sum(visits),bikes))

# %%
Verdun_net_balance20190709 = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/net_balance2019-07-09.csv')
Verdun_net_balance20190709 = Verdun_net_balance20190709.drop(columns=['Unnamed: 0'])

Verdun_net_balance20190710 = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/net_balance2019-07-10.csv')
Verdun_net_balance20190710 = Verdun_net_balance20190710.drop(columns=['Unnamed: 0'])

Verdun_net_balance20190711 = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/net_balance2019-07-11.csv')
Verdun_net_balance20190711 = Verdun_net_balance20190711.drop(columns=['Unnamed: 0'])

Verdun_net_balance20190712 = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/net_balance2019-07-12.csv')
Verdun_net_balance20190712 = Verdun_net_balance20190712.drop(columns=['Unnamed: 0'])

Verdun_net_balance20190713 = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/net_balance2019-07-13.csv')
Verdun_net_balance20190713 = Verdun_net_balance20190713.drop(columns=['Unnamed: 0'])

Verdun_net_balance20190714 = pd.read_csv('/Users/Neversound/Desktop/MGSC662Proj/net_balance2019-07-14.csv')
Verdun_net_balance20190714 = Verdun_net_balance20190714.drop(columns=['Unnamed: 0'])

# %%
# daily_cost,costs,visits,before,after,bikes_rebalanced,bikes = hour_rebalance(Verdun_net_balance20190714)
